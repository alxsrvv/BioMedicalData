# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np
x = np.linspace(0, 5, 11)
y = x ** 2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
#func method
plt.plot(x, y)
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Sample plot')
# Out:
# Text(0.5, 1.0, 'Sample plot')

# %%
plt.subplot(1, 2, 1)
plt.plot(x, y, 'g')
plt.subplot(1, 2, 2)
plt.plot(y, x, 'y')

# %%
#oop method
fg = plt.figure()

axes_1 = fg.add_axes([0, 0, 1, 1])

axes_1.plot(x, y)
axes_1.set_xlabel('X axis')
axes_1.set_ylabel('Y axis')
axes_1.set_title('OO plot')
# Out:
# Text(0.5, 1.0, 'OO plot')

# %%
fg = plt.figure()

axes_1 = fg.add_axes([0, 0, 1, 1])
axes_2 = fg.add_axes([0.1, 0.5, 0.4, 0.3])

axes_1.plot(x, y, 'b')
axes_1.set_xlabel('X axis')
axes_1.set_ylabel('Y axis')
axes_1.set_title('OO 1 plot')

axes_2.plot(x, y, 'r')
axes_2.set_xlabel('X axis')
axes_2.set_ylabel('Y axis')
axes_2.set_title('OO 2 plot')
# Out:
# Text(0.5, 1.0, 'OO 2 plot')

# %%
fg, axes = plt.subplots()

axes.plot(x, y)
axes.set_xlabel('X axis')
axes.set_ylabel('Y axis')
axes.set_title('OO plot')
# Out:
# Text(0.5, 1.0, 'OO plot')

# %%
fg, axes = plt.subplots(nrows = 1, ncols = 2)

axes[0].plot(x, y)
axes[1].plot(y, x)

# %%
#debug
fg, axes = plt.subplots(nrows = 4, ncols = 4)
plt.tight_layout()

# %%
fg = plt.figure()

axes = fg.add_axes([0, 0, 1, 1])

axes.plot(x, x**2, label = 'x^2')
axes.plot(x, x**3, label = 'x^3')
axes.legend()

# %%
#size and dpi changing
fg = plt.figure(figsize = (8, 4), dpi = 100)

# %%
fg, axes = plt.subplots()
axes.plot(x, y, lw = 5, ls = '--')

# %%
fg, axes = plt.subplots()
axes.plot(x, y, marker = 'o', 
          markersize = 20, 
          markerfacecolor = 'r')

# %%
fg.savefig('test_figure_plt.png')

# %%
plt.scatter(x, y)

# %%
from random import sample
data = sample(range(1, 1000), 100)
plt.hist(data)
# Out:
# (array([10.,  6.,  8.,  7., 11., 11., 13., 10., 13., 11.]),
#  array([ 24. , 121.5, 219. , 316.5, 414. , 511.5, 609. , 706.5, 804. ,
#         901.5, 999. ]),
#  <a list of 10 Patch objects>)

# %%
data = [np.random.normal(0, std, 100) for std in range(1, 4)]

plt.boxplot(data, vert = True, patch_artist = True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x270b2353070>,
#   <matplotlib.lines.Line2D at 0x270b2353340>,
#   <matplotlib.lines.Line2D at 0x270b2319fa0>,
#   <matplotlib.lines.Line2D at 0x270b236f220>,
#   <matplotlib.lines.Line2D at 0x270b2386d00>,
#   <matplotlib.lines.Line2D at 0x270b2386790>],
#  'caps': [<matplotlib.lines.Line2D at 0x270b2353a90>,
#   <matplotlib.lines.Line2D at 0x270b2353550>,
#   <matplotlib.lines.Line2D at 0x270b236f5b0>,
#   <matplotlib.lines.Line2D at 0x270b236fee0>,
#   <matplotlib.lines.Line2D at 0x270b2386670>,
#   <matplotlib.lines.Line2D at 0x270b2386340>],
#  'boxes': [<matplotlib.patches.PathPatch at 0x270b24c8b80>,
#   <matplotlib.patches.PathPatch at 0x270b2319d60>,
#   <matplotlib.patches.PathPatch at 0x270b236fa30>],
#  'medians': [<matplotlib.lines.Line2D at 0x270b2319730>,
#   <matplotlib.lines.Line2D at 0x270b236fc10>,
#   <matplotlib.lines.Line2D at 0x270b1def430>],
#  'fliers': [<matplotlib.lines.Line2D at 0x270b2319cd0>,
#   <matplotlib.lines.Line2D at 0x270b236ffd0>,
#   <matplotlib.lines.Line2D at 0x270b1def8b0>],
#  'means': []}
